# %%
import seaborn as sn
df=sn.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sn.__version__
# Out:
# '0.11.2'

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#Question-1
# Write a program to load penguins dataset from seaborn and plot histplot/displot for the flipper_length_mm.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
#print(df.head())
sn.displot(x=df['flipper_length_mm'])
#sn.histplot(x=df['flipper_length_mm'])

# %%
#Question-2
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm with bin width=3

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],height=3)

# %%
#Question-3
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm with
# number of bin=20

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],bins=20)

# %%
#Question-4
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm
# with hue='species'.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],hue=None,hue_order='species')

# %%
#Question-5
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm with kind='kde'.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],kind='kde')

# %%
#Question-6
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm with kind='kde'
# and hue='species'.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],hue=None,hue_order='species',kind='kde')

# %%
#Question-7
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm 
# with kind='ecdf'.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],kind='ecdf')

# %%
#Question-8
# Write a program to load penguins datset from seaborn and plot histplot/displot for the flipper_lenght_mm and
# bill_depth_mm with hue='species'.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.displot(x=df['flipper_length_mm'],y=df['bill_depth_mm'],hue=None,hue_order='species')

# %%
#Question-9
#Write a program to load penguins dataset from seaborn and plot jointplot for the flipper_length_mm and bill_depth_mm
# with hue='species'

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.jointplot('flipper_length_mm','bill_depth_mm',data=df,kind='hex')
# Out:
# C:\Users\91630\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Question-10
# Write a program to load penguins datset from seaborn and plot a pairplot for penguins dataframe.

# %%
import seaborn as sn
df=sn.load_dataset('penguins')
sn.pairplot(df)

# %%
import seaborn as sn
df=sn.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Question-11
# Write a program to load tips dataset from seaborn and plot boxplot for total_bill on each day.

# %%
import seaborn as sn
df=sn.load_dataset('tips')
sn.boxplot(x=df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#Question-12
# Write a program to load tips dataset from seaborn and plot boxplot for total_bill on each day. With hue='smoker'

# %%
import seaborn as sn
df=sn.load_dataset('tips')
sn.boxplot(x=df['total_bill'],hue=None,hue_order='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#Question-13
# Write a program to load tips dataset from seaborn and plot violinplot faor total_bill on each day.With hue='sex'.

# %%
import seaborn as sn
df=sn.load_dataset('tips')
sn.violinplot(x=df['total_bill'],hue=None,hue_order='sex')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#Question-14
# Write a program to load tips dataset from seaborn and plot plot regression line between total_bill and tip 
# with 95% confidence interval.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sn.load_dataset('tips')
sns.regplot(data=df,x='total_bill',y='tip', ci=95)
plt.show()

# %%
#Question-15
#write a program to load tips dataset from seaborn and plot pairplot with x_vars as 'total_bill' and 'size' , y_vars='tips'

# %%
import seaborn as sn
df=sn.load_dataset('tips')
sn.pairplot(df,x_vars=['total_bill','size'],y_vars=['tip'])
