# %%
#Question-1
# write a python program to plot the normal distribution function with mu=0.5 and Ʃ=1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
x = np.arange(-3, 3, 0.001)
plt.plot(x, norm.pdf(x,0.5,1))

# %%
#Question-2
# write a python program to plot the normal continuous random distribution for random variables

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
x = np.arange(-3, 3, 0.01)
plt.plot(x, norm.pdf(x, 0, 1), color='red', linewidth=3)
pt.show()

# %%
#Question-3
# Write a python program to plot the distribution of the given plot creating normal continuous random variable

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(170, 10, 250)
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
plt.show()

# %% [markdown]
# ![Q4.jpg](attachment:Q4.jpg)

# %%
# importing library
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
numargs = norm.numargs
a, b = 4.32, 3.18
rv = norm(a, b)
quantile = np.arange (0.01, 1, 0.1)
R = norm.rvs(a, b)
R = norm.pdf(a, b, quantile)
distribution = np.linspace(0, np.minimum(rv.dist.b, 3))
plot = plt.plot(distribution, rv.pdf(distribution))

# %% [markdown]
# ![Q5.jpg](attachment:Q5.jpg)

# %%
from scipy.stats import hypsecant  
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 100)
# Varying positional arguments
y1 = hypsecant .pdf(x, 1,3)
y2 = hypsecant .pdf(x, 1,4)
plt.plot(x, y1, "*", x, y2, "r--")
plt.show()

# %%
#Question-6
# Write a python program to implement of normal distribution with data of in range of 1-50

# %%
 import numpy as np
import matplotlib.pyplot as plt
# Creating a series of data of in range of 1-50.
x = np.linspace(1,50,200)
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density
mean = np.mean(x)
sd = np.std(x)
pdf = normal_dist(x,mean,sd)
plt.plot(x,pdf , color = 'green')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
plt.show()

# %%
#Question-7
# Generate a random normal distribution of size 2*3 with mean at 1 and standard deviation of 2:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
x_axis = np.arange(-10,10,0.001)
mean = 1
sd = 2
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %% [markdown]
# ![Q8.jpg](attachment:Q8.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
x_axis = np.arange(-4,4,0.001)
plt.plot(x_axis, norm.pdf(x_axis))
plt.show()

# %% [markdown]
# ![Q9.jpg](attachment:Q9.jpg)

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
data = np.arange(1,10,0.01)
pdf = norm.pdf(data , loc = 5.3 , scale = 1 ) 
sb.set_style('whitegrid')
sb.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')

x=norm(loc = 5.3 , scale = 1).cdf(4.5)
print(x)
print(x*100)
plt.show()
# Out:
# 0.21185539858339675
# 21.185539858339673

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![Q10.jpg](attachment:Q10.jpg)

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
data = np.arange(1,10,0.01)
pdf = norm.pdf(data , loc = 5.3 , scale = 1 ) 
sb.set_style('whitegrid')
sb.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')

cdf_upper_limit = norm(loc = 5.3 , scale = 1).cdf(6.5)
cdf_lower_limit = norm(loc = 5.3 , scale = 1).cdf(4.5)
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
print(prob*100)
plt.show()
# Out:
# 0.673074931194895
# 67.30749311948951

# %% [markdown]
# ![Q11.jpg](attachment:Q11.jpg)

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
data = np.arange(1,10,0.01)
pdf = norm.pdf(data , loc = 5.3 , scale = 1 ) 
sb.set_style('whitegrid')
sb.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')

cdf_value = norm(loc = 5.3 , scale = 1).cdf(6.5)
prob = 1- cdf_value
print(prob)
print(prob*100)
plt.show()
# Out:
# 0.11506967022170822
# 11.506967022170823

# %% [markdown]
# ![Q12.jpg](attachment:Q12.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
x_axis = np.arange(-60,60)
mean = 5
sd = 10
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
pt.title('Normal Distribution (Mean=5,STD=10)')
pt.xlabel('Values of Random Variable x')
pt.ylabel('Probability')
plt.show()

# %% [markdown]
# ## ![Q13.jpg](attachment:Q13.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
x = np.arange(-10, 10, 0.001)
plt.plot(x, norm.pdf(x, 0, 1.5))
plt.plot(x, norm.pdf(x, 0, 1))
plt.plot(x, norm.pdf(x, 0, 2.2))
plt.title('Normal Distribution')
plt.xlabel('Values of Random Variable X')
plt.ylabel('Probability')
plt.show()

# %%
#Question-14
# Generate a random normal distribution of size 2*3

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed
from numpy.random import normal
data = normal(loc=0, scale=1, size=200)
count, bins, ignored = plt.hist(data, 30)
plt.show()
